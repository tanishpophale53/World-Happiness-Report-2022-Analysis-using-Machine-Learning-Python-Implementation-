# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishpophale53/World-Happiness-Report-2022-Analysis-using-Machine-Learning-Python-Implementation-/blob/main/World_Happiness_Report_2022_Analysis_using_Machine_Learning_(Python_Implementation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing Dataset

# %%
data=pd.read_csv('/content/happiness_rankings.csv')

# %% [markdown]
# Printing first 5 rows of a Dataset

# %%
data.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %% [markdown]
# Printing the dimension of a Dataset

# %%
data.shape
# Out:
# (146, 12)

# %% [markdown]
# Printing last 5 rows of a Dataset

# %%
data.tail()
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 141   142     Botswana            3.471         3.667        3.275
# 142   143       Rwanda            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 141                       0.187                         1.503
# 142                       0.536                         0.785
# 143                       0.548                         0.947
# 144                       0.216                         1.392
# 145                       1.263                         0.758
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 141                         0.815                                  0.280
# ...

# %% [markdown]
# Printing column names of a Dataset as a list

# %%
data.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %% [markdown]
# Describing Dataset with some general entities

# %%
data.describe()
# Out:
#              RANK  Happiness score  Whisker-high  Whisker-low  \
# count  146.000000       146.000000    146.000000   146.000000
# mean    73.500000         5.553575      5.673589     5.433568
# std     42.290661         1.086843      1.065621     1.109380
# min      1.000000         2.404000      2.469000     2.339000
# 25%     37.250000         4.888750      5.006250     4.754750
# 50%     73.500000         5.568500      5.680000     5.453000
# 75%    109.750000         6.305000      6.448750     6.190000
# max    146.000000         7.821000      7.886000     7.756000
#
#        Dystopia (1.83) + residual  Explained by: GDP per capita  \
# count                  146.000000                    146.000000
# mean                     1.831808                      1.410445
# std                      0.534994                      0.421663
# min                      0.187000                      0.000000
# 25%                      1.555250                      1.095500
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        146 non-null    int64
#  1   Country                                     146 non-null    object
#  2   Happiness score                             146 non-null    float64
#  3   Whisker-high                                146 non-null    float64
#  4   Whisker-low                                 146 non-null    float64
#  5   Dystopia (1.83) + residual                  146 non-null    float64
#  6   Explained by: GDP per capita                146 non-null    float64
#  7   Explained by: Social support                146 non-null    float64
#  8   Explained by: Healthy life expectancy       146 non-null    float64
# ...

# %% [markdown]
# Printing the no of null values present in each column of a Dataset

# %%
data.isnull().sum()
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               0
# Whisker-high                                  0
# Whisker-low                                   0
# Dystopia (1.83) + residual                    0
# Explained by: GDP per capita                  0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# Grouping, Summing and Sorting the values of 'Country' column by 'Happiness score' in a Dataset

# %%
data_country=data.groupby('Country').sum()
data_country.sort_values(by= 'Happiness score', ascending=  False)
# Out:
#              RANK  Happiness score  Whisker-high  Whisker-low  \
# Country
# Cyprus        120           11.688        11.929       11.447
# Finland         1            7.821         7.886        7.756
# Denmark         2            7.636         7.710        7.563
# Iceland         3            7.557         7.651        7.464
# Switzerland     4            7.512         7.586        7.437
# ...           ...              ...           ...          ...
# Botswana      142            3.471         3.667        3.275
# Rwanda        143            3.268         3.462        3.074
# Zimbabwe      144            2.995         3.110        2.880
# Lebanon       145            2.955         3.049        2.862
# Afghanistan   146            2.404         2.469        2.339
#
#              Dystopia (1.83) + residual  Explained by: GDP per capita  \
# Country
# Cyprus                            3.122                         3.630
# ...

# %%
data_country.sort_values(by= 'Happiness score', ascending=  False).head()
# Out:
#              RANK  Happiness score  Whisker-high  Whisker-low  \
# Country
# Cyprus        120           11.688        11.929       11.447
# Finland         1            7.821         7.886        7.756
# Denmark         2            7.636         7.710        7.563
# Iceland         3            7.557         7.651        7.464
# Switzerland     4            7.512         7.586        7.437
#
#              Dystopia (1.83) + residual  Explained by: GDP per capita  \
# Country
# Cyprus                            3.122                         3.630
# Finland                           2.518                         1.892
# Denmark                           2.226                         1.953
# Iceland                           2.320                         1.936
# Switzerland                       2.153                         2.026
#
#              Explained by: Social support  \
# Country
# Cyprus                              1.797
# Finland                             1.258
# ...

# %%
data_country.sort_values(by= 'Happiness score', ascending=  False).tail()
# Out:
#              RANK  Happiness score  Whisker-high  Whisker-low  \
# Country
# Botswana      142            3.471         3.667        3.275
# Rwanda        143            3.268         3.462        3.074
# Zimbabwe      144            2.995         3.110        2.880
# Lebanon       145            2.955         3.049        2.862
# Afghanistan   146            2.404         2.469        2.339
#
#              Dystopia (1.83) + residual  Explained by: GDP per capita  \
# Country
# Botswana                          0.187                         1.503
# Rwanda                            0.536                         0.785
# Zimbabwe                          0.548                         0.947
# Lebanon                           0.216                         1.392
# Afghanistan                       1.263                         0.758
#
#              Explained by: Social support  \
# Country
# Botswana                            0.815
# Rwanda                              0.133
# ...

# %% [markdown]
# Plotting Bar plot between 'Country' & 'Happiness Score' column of a Dataset

# %%
plt.subplots(figsize=(30,10))
cr=data_country['Happiness score'].sort_values(ascending=False)
ax=cr.plot.bar()
ax.set_xlabel('Country')
ax.set_ylabel('Happiness score')
ax.set_title("country Rank Wise Happiness Score")
plt.show()
print(cr)
# Out:
# Country
# Cyprus         11.688
# Finland         7.821
# Denmark         7.636
# Iceland         7.557
# Switzerland     7.512
#                 ...
# Botswana        3.471
# Rwanda          3.268
# Zimbabwe        2.995
# Lebanon         2.955
# Afghanistan     2.404
# Name: Happiness score, Length: 145, dtype: float64

# %% [markdown]
# Plotting the Heatmap

# %%
fig,ax=plt.subplots(figsize=(14,8))
sns.heatmap(data.corr(), annot=True, cmap='viridis')

# %%
data.drop(['Happiness score'], axis=1).hist(edgecolor= 'white',
                                            linewidth=0.5,
                                            figsize=(19,8), grid=False,
                                            color='orange')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3f4659ff90>,
# ...
#       dtype=object)

# %%
data.drop('Happiness score', axis=1).plot(subplots= True, figsize=(16,12))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3f465f9310>,
# ...
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.Country=le.fit_transform(data.Country)

# %%
x=data.drop(['RANK'], axis=1)
y=data["RANK"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
sdata=scale.fit_transform(x.drop(['Country'], axis=1))

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(x,y,test_size=0.2)

# %%
model=LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(X_test)

# %%
print("Training Accuracy: ", model.score(X_train, Y_train))
print("Testing Accuracy: ", model.score(X_test, Y_test))
# Out:
# Training Accuracy:  0.9681154677421482
# Testing Accuracy:  0.9617967352956065

# %%
model.get_params(deep= True)
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
model1=model.fit(X_train, Y_train)
pred=model.predict(X_test)
model.score(X_test, Y_test)
# Out:
# 0.9617967352956065
